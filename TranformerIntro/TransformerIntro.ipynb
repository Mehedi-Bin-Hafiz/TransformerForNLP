# %%
# pip install transformers
# Out:
# ...
#   Using cached transformers-4.10.2-py3-none-any.whl (2.8 MB)
# ...
#   Using cached regex-2021.8.28-cp37-cp37m-win_amd64.whl (270 kB)
# ...
#   Using cached tokenizers-0.10.3-cp37-cp37m-win_amd64.whl (2.0 MB)
# ...
#   Using cached tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# ...
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# ...
#   Using cached sacremoses-0.0.45-py3-none-any.whl (895 kB)
# ...
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# ...
#   Using cached huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
# ...
#   Using cached certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# ...
#   Using cached urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# ...
#   Using cached charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# ...
#   Using cached idna-3.2-py3-none-any.whl (59 kB)
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
#   Using cached click-8.0.1-py3-none-any.whl (97 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Transformers is actually pretrained models for Natural Language Understanding task(sentiment). Natural language generation(translator)

# %%
from transformers import pipeline #help to call pretraind model
classifier = pipeline('sentiment-analysis') #it called distilbert architecture
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
classifier('we are very happy to show you!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998583793640137}]

# %%
classifier('this is not bad')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9996947050094604}]

# %%
classifier(['This is not so good','my name is mehedi'])
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9997946619987488},
#  {'label': 'POSITIVE', 'score': 0.9927682876586914}]
